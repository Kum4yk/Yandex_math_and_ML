# %% [markdown]
# **1. Мы работаем с классификатором classifier = linear_model.[SGDClassifier()](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html). Мы хотим подобрать параметры модели с помощью поиска по сетке, а для этого нам хочется предварительно получить набор доступных параметров модели с их значениями. Какая из перечисленных команд позволяет это сделать?**
#
#
#  - classifier.params()
#
#
#  - classifier.params
#
#
#  - classifier.params_
#
#
#  - *classifier.get_params()*
#
# ___
#
# **2. Какой из перечисленных параметров нельзя передать в [grid_search.GridSearchCV(...)](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) для подбора параметров модели по сетке?**
#
#
#  - scoring
#
#
#  - *n_iter*
#
#
#  - cv
#
# ___
#
# **3. Мы работаем с объектом grid_cv = [grid_search.GridSearchCV(classifier, parameters_grid)](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html), реализующим функциональность поиска по сетке. После того, как мы провели поиск по сетке с помощью метода fit, нам нужно получить лучшую модель. Какая команда позволяет это сделать?**
#
#
#  - grid_cv.get_best_model()
#
#
#  - grid_cv.get_best_estimator()
#
#
#  - grid_cv.best_model
#
#
#  - *grid_cv.best_estimator_*
#
# ___
#
# **4. Мы работаем с объектом grid_cv = grid_search.GridSearchCV(classifier, parameters_grid), реализующим функциональность поиска по сетке. Здесь classifier = linear_model.SGDClassifier(). После того, как мы провели поиск по сетке с помощью метода fit, нам нужно получить набор лучших параметров модели classifier. Какая команда позволяет это сделать?**
#
#
#  - classifier.best_params_ (-)
#
#
#  - grid_cv.get_params()
#
#
#  - *grid_cv.best_params_*
#
#
#  - classifier.get_params()
#
# ___
#
# **5. Какой класс позволяет построить цепочку преобразований для обработки данных?**
#
#
#  - *sklearn.pipeline.Pipeline*
#
#
#  - sklearn.pipeline.Chain
#
#
#  - sklearn.preprocessing.Pipeline
#
# ___
#
# **6. Какую функциональность реализует объект [StandardScaler()](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) из модуля sklearn.preprocessing?**
#
#
#  - Заполнение пропущенных значений в данных.
#
#
#  - *Нормализация данных.*
#
#
#  - Фильтрация данных согласно условию, передаваемому объекту StandardScaler() в качестве аргумента.
