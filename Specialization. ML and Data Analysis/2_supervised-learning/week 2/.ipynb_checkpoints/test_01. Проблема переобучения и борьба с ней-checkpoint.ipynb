# %% [markdown]
# 1. Выберите верные утверждения про переобучение.
#
#
# - Одним из объяснений эффекта переобучения является недостаточная сложность модели, не позволяющая улавливать закономерности в данных.
# (-)
#
#
# - Симптомом переобучения для линейных моделей являются большие абсолютные значения весов.
# (+)
#
#
# - Переобучение — явление, при котором полученный при обучении алгоритм показывает на новых данных более низкое качество, чем на обучающей выборке.
# (+)
#
#
# - Переобучение — явление, при котором полученный при обучении алгоритм показывает сопоставимое качество на обучающей выборке и на новых данных.
# (-)

# %% [markdown]
# 2. Какой вид регуляризатора позволяет проводить отбор признаков?
#
#
#  - Регуляризация не имеет отношения к отбору признаков
#
#
# - L2-регуляризатор
#
#
# - L1-регуляризатор
# (+)

# %% [markdown]
# 3. Каковы недостатки оценки качества алгоритма по отложенной выборке?
#
#
#  - Необходимо многократное обучение алгоритма.
#
#
# - Оценка существенно зависит от способа разбиения выборки на обучающую и отложенную.
# (+)
#
#
# - Сокращается объём обучающей выборки.
# (+)

# %% [markdown]
# 4. Предположим, что вы решаете задачу восстановления регрессии, используя полиномиальную модель $a(x;w,k)=w_0+w_1x+⋯+w_kx^k$, в качестве оптимизируемого функционала используется регуляризованная среднеквадратичная ошибка $Q(w,k,X,λ)=\frac{1}{ℓ}∑^ℓ_{i=1}(a(x_i;w,k)−y_i)^2+λ||w||^2$. Что в данной задаче является гиперпараметрами?
#
#
#  - k
#  (+ степень полинома)
#
#
#  - $ w_1, \dots, w_k$
#
#
#  - $\lambda$
#  (+ штраф)
#
#
#  - $\ell$

# %% [markdown]
# 5. Предположим, вы оцениваете качество работы алгоритма при помощи кросс-валидации с разбиением на $k$ блоков. Сколько раз будет проведено обучение модели?
#
#
#  - $k^2$
#
#
#  - $k$
#  (+)
#
#
#  - $1$
#
#
#  - $\frac{k(k-1)}{2} $
