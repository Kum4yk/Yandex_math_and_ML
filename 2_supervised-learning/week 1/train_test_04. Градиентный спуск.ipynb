# %% [markdown]
# 1. Почему в градиентном спуске на каждой итерации делается шаг в сторону антиградиента?
#  - Антиградиент легко найти, в отличие от других направлений.
#  - Антиградиент функционала ошибки зависит только от одного объекта.
#  - Антиградиент совпадает с направлением наискорейшего убывания. + (Таким образом ошибка на выборке на каждой итерации минимизируется.)

# %% [markdown]
# 2. Градиент какой функции/функционала и по какому аргументу используется в градиентном спуске при обучении линейной регрессии?
#  - Функционала ошибки — например, среднеквадратичной ошибки — по вектору весов. (+ Такой градиент показывает в какую сторону нужно сдвинуть веса, чтобы уменьшить ошибку на выборке.)
#  - Алгоритма — то есть скалярного произведение вектора признаков —по вектору весов.
#  - Функционала ошибки — например, среднеквадратичной ошибки — по прогнозам алгоритма.
