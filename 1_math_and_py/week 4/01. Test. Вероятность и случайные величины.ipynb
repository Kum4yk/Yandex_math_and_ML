# %% [markdown]
# 1. Основной предмет изучения математической статистики — это
#  - методы восстановления свойств случайных величин на основании конечных выборок из них. (+)
#  - математические модели случайных величин и их свойства.

# %% [markdown]
# 2. Предположим, что в некоторой популяции вероятность дожить до 60 лет равна 0.5, а вероятность дожить до 80 лет — 0.2. Какова вероятность, что случайно выбранный шестидесятилетний представитель популяции доживёт до восьмидесяти? Запишите ответ с точностью до одного знака после десятичной точки (задавать разделитель в этой задаче и следующих нужно именно в виде точки).
#
#
# 0.4

# %% [markdown]
# 3. 1% женщин больны раком груди. У 80% женщин, больных раком груди, маммограмма верно выявляет наличие заболевания; кроме того, она даёт ложный положительный результат (то есть, неверно показывает наличие рака) для 9.6% здоровых женщин.
#
#     У какого процента женщин, маммограмма которых дала положительный результат, есть рак груди? Запишите ответ с точностью до одного знака после десятичной точки (знак процента не нужен).
#
#
# 7.8

# %% [markdown]
# 4. Какова вероятность того, что при независимом подбрасывании двух симметричных шестигранных кубиков хотя бы на одном из них выпадет больше трёх очков? Запишите точный ответ в виде десятичной дроби.
#
# Хотя бы на одном = 1 - не на одном не выпадет
# $$ p = 1 - \frac1{2} \cdot \frac1{2} = \frac3{4} $$

# %% [markdown]
# 5. Какие из перечисленных ниже распределений являются дискретными?
#  - Пуассона (+)
#  - Бернулли (+)
#  - Биномиальное (+)
#  - Равномерное на отрезке (-)
#  - Нормальное (-)

# %% [markdown]
# 6. Какое распределение точнее всего описывает число выпавших шестёрок при десяти независимых подбрасываниях симметричного шестигранного кубика?
#  - Дискретное распределение, принимающее целочисленные значения от 0 до 10 с равными вероятностями $\frac1{11} $
#  - Распределение Бернулли с параметром $ p=\frac1{6}$
#  - Биномиальное с параметрами n=10, $p=\frac1{6}$ (+)
#  - Нормальное распределение с параметрами $\mu=\frac{10}{6}$, $\sigma^2 = 10\cdot\frac{1}{6}\cdot\frac{5}{6} = \frac{25}{12}$

# %% [markdown]
# 7. Какие из приведённых величин, скорее всего, можно моделировать с помощью распределения Пуассона?
#  - Результат выпадения симметричного шестигранного кубика. (-)
#  - Количество изюма в булочках с изюмом. (+)
#  - Количество людей в очереди на кассу в супермаркете. (+)
#  - Точное время прихода на работу. (-)
#  - Число попаданий в баскетбольное кольцо за $ n $ попыток. (-)

# %% [markdown]
# 8. Распределение каких из приведённых величин, скорее всего, похоже на нормальное?
#  - Количество троллейбусов №28, проезжающих за час мимо остановки "Улица Льва Толстого".(-)
#  - Выборочное среднее выборки объёма 100. (?)
#  - Результат подбрасывания монетки. (-)
#  - Срок службы батарейки. (+)
#  - Погрешность барометра. (+)

# %% [markdown]
# 9. С помощью каких из приведённых функций можно задавать распределения непрерывных случайных величин?
#  - Функция непрерывного распределения вероятности плотности. -
#  - Функция вероятности -
#  - Функция распределения. (+)
#  - функция плотности вероятности (+)

# %% [markdown]
# 10. Функция распределения случайной величины обладает следующими свойствами:
#  - Она принимает значения на отрезке $[0,1]$. (+)
#  - В каждой точке x она равна вероятности того, что случайная величина не меньше x.
#  - Если у случайной величины существует плотность, то в каждой точке x функция распределения равна интегралу от плотности от минус бесконечности до x. (+)
#  - Она монотонно невозрастает по x.

# %% [markdown]
# https://habr.com/ru/post/408775/
