# %% [markdown]
# ---
# ---
# ### 1
# В каких ситуациях лучше не использовать АБ-тестирование?
#
#
# - Когда мы проверяем эффективность какой-то совершенно новой функции нашего продукта, введение которой полностью меняет пользовательский сценарий
#
#
# - Когда мы плохо понимаем, как и зачем пользователь взаимодействует с нашим продуктом, — в таком случае лучше провести фокус-группу

# %% [markdown]
# ---
# ---
# ### 2
# Выберите верные утверждения о дизайне АБ-тестов.
#
#
# - Рандомизация, то есть, случайное распределение пользователей по экспериментальным группам, автоматически балансирует их по всем демографическим показателям
#
#
# - Если мы хотим показать каждому пользователю два варианта функциональности, нужно, чтобы это делалось в случайном порядке, иначе между группами возникает систематическое различие

# %% [markdown]
# ---
# ---
# ### 3
# Какие требования предъявляют к offline метрикам качества?
#
#
# - Корреляция с online метриками качества
#
#
# - Возможность расчета в offline по историческим данным

# %% [markdown]
# ---
# ---
# ### 4
# Как провести АБ-тест в случае, когда отсутствует возможность напрямую измерить KPI (ключевой бизнес показатель) метрику непосредственно во время эксперимента?
#
#
# - Использовать промежуточную proxy-метрику, которая согласована с KPI-метрикой и которую можно измерить непосредственно во время эксперимента.
